# %% [markdown]
# # Before you start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents. Please, load the data using Ironhack's database (db: employees, table: employees_advanced).

# %%
# Your code here:
salaries = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
# Your code here:
salaries.head(10)
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 5  DUBERT,  TOMASZ    PARAMEDIC I/C       FIRE                 F
# 6   EDWARDS,  TIM P      LIEUTENANT       FIRE                 F
# 7   ELKINS,  ERIC J        SERGEANT     POLICE                 F
# 8  ESTRADA,  LUIS F  POLICE OFFICER     POLICE                 F
# 9   EWING,  MARIE A       CLERK III     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# 0           Salary            NaN    $107790.00         NaN
# 1           Salary            NaN    $104628.00         NaN
# 2           Salary            NaN    $114324.00         NaN
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
salaries.isna().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
salaries['Salary or Hourly'].value_counts()
# Out:
# Salary    24775
# Hourly     7883
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
count_employees  = salaries.groupby('Department').agg({'Job Titles':'count'}).sort_values(by = 'Job Titles', ascending = False)
count_employees
# Out:
#                        Job Titles
# Department
# POLICE                      12973
# FIRE                         4800
# STREETS & SAN                2194
# OEMC                         2044
# WATER MGMNT                  1878
# AVIATION                     1612
# TRANSPORTN                   1103
# GENERAL SERVICES              972
# PUBLIC LIBRARY                932
# FAMILY & SUPPORT              621
# FINANCE                       575
# HEALTH                        516
# LAW                           405
# CITY COUNCIL                  400
# BUILDINGS                     266
# COMMUNITY DEVELOPMENT         214
# BUSINESS AFFAIRS              168
# BOARD OF ELECTION             112
# DoIT                          101
# PROCUREMENT                    86
# MAYOR'S OFFICE                 85
# CITY CLERK                     85
# CULTURAL AFFAIRS               76
# ANIMAL CONTRL                  73
# HUMAN RESOURCES                68
# INSPECTOR GEN                  63
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:

# Two-sided test:
# H0: hourly wage of all hourly workers  = $30/hr
# H1: hourly wage of all hourly workers is significantly different, != $30/hr

# %%
hourly_employees = salaries[salaries['Salary or Hourly'] == 'Hourly']
hourly_employees
# Out:
#                          Name                      Job Titles  \
# 11           FITCH,  JORDAN M                       LAW CLERK
# 54          ABASCAL,  REECE E     TRAFFIC CONTROL AIDE-HOURLY
# 56      ABBATACOLA,  ROBERT J             ELECTRICAL MECHANIC
# 57         ABBATE,  JOSEPH L          POOL MOTOR TRUCK DRIVER
# 60           ABBOTT,  BETTY L              FOSTER GRANDPARENT
# ...                       ...                             ...
# 32639        ZUREK,  FRANCIS              ELECTRICAL MECHANIC
# 32643  ZWARYCZ MANN,  IRENE A                  CROSSING GUARD
# 32644      ZWARYCZ,  THOMAS J         POOL MOTOR TRUCK DRIVER
# 32650        ZYGADLO,  JOHN P          MACHINIST (AUTOMOTIVE)
# 32651     ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE
#
#              Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 11                  LAW                 F           Hourly           35.0
# ...

# %%
hourly_employees['Hourly Rate'] = hourly_employees['Hourly Rate'].str.replace("[$,]", "", regex=True)
hourly_employees.head()
# Out:
#                      Name                   Job Titles        Department  \
# 11       FITCH,  JORDAN M                    LAW CLERK               LAW
# 54      ABASCAL,  REECE E  TRAFFIC CONTROL AIDE-HOURLY              OEMC
# 56  ABBATACOLA,  ROBERT J          ELECTRICAL MECHANIC          AVIATION
# 57     ABBATE,  JOSEPH L       POOL MOTOR TRUCK DRIVER     STREETS & SAN
# 60       ABBOTT,  BETTY L           FOSTER GRANDPARENT  FAMILY & SUPPORT
#
#    Full or Part-Time Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# 11                 F           Hourly           35.0           NaN       14.51
# 54                 P           Hourly           20.0           NaN       19.66
# 56                 F           Hourly           40.0           NaN       46.10
# 57                 F           Hourly           40.0           NaN       35.60
# 60                 P           Hourly           20.0           NaN        2.65

# %%
hourly_employees['Hourly Rate'] = hourly_employees['Hourly Rate'].astype(float)

# %%
hourly_employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7883 entries, 11 to 32651
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7883 non-null   object
#  1   Job Titles         7883 non-null   object
#  2   Department         7883 non-null   object
#  3   Full or Part-Time  7883 non-null   object
#  4   Salary or Hourly   7883 non-null   object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      0 non-null      object
#  7   Hourly Rate        7883 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 554.3+ KB

# %%
from scipy.stats import ttest_1samp

stat, pval = ttest_1samp(hourly_employees['Hourly Rate'], 30)

# %%
print('stat is  ', stat)
print('P-value for the two-tailed test is ', pval)
# Out:
# stat is   21.003532193332216
# P-value for the two-tailed test is  2.4048011351057683e-95

# %% [markdown]
# **Answer:**
# The P-value is less than 0.05, which means we reject $H_0:$  (_hourly wage of all hourly workers  = $30/hr_)

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
# One-sided test:
# H0: mean of police's salaries this year are <= $86000/year
# H1: mean of police's salaries this year are > $86000/year

# %%
type_d = ['POLICE']
police_salary = salaries[salaries['Department'].isin(type_d) & salaries['Annual Salary']]
police_salary
# Out:
#                         Name      Job Titles Department Full or Part-Time  \
# 1            BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 4           DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 7            ELKINS,  ERIC J        SERGEANT     POLICE                 F
# 8           ESTRADA,  LUIS F  POLICE OFFICER     POLICE                 F
# 9            EWING,  MARIE A       CLERK III     POLICE                 F
# ...                      ...             ...        ...               ...
# 32652       ZYGMUNT,  DAWID   POLICE OFFICER     POLICE                 F
# 32653     ZYGOWICZ,  PETER J  POLICE OFFICER     POLICE                 F
# 32654  ZYLINSKA,  KATARZYNA   POLICE OFFICER     POLICE                 F
# 32655      ZYMANTAS,  MARK E  POLICE OFFICER     POLICE                 F
# 32656    ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE                 F
#
#       Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# ...

# %%
police_salary['Annual Salary'] = police_salary['Annual Salary'].str.replace("[$,]", "", regex=True)
police_salary['Annual Salary'] = police_salary['Annual Salary'].astype(float)
police_salary.head()
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 7   ELKINS,  ERIC J        SERGEANT     POLICE                 F
# 8  ESTRADA,  LUIS F  POLICE OFFICER     POLICE                 F
# 9   EWING,  MARIE A       CLERK III     POLICE                 F
#
#   Salary or Hourly  Typical Hours  Annual Salary Hourly Rate
# 1           Salary            NaN       104628.0         NaN
# 4           Salary            NaN       111474.0         NaN
# 7           Salary            NaN       104628.0         NaN
# 8           Salary            NaN        96060.0         NaN
# 9           Salary            NaN        53076.0         NaN

# %%
stat, pval = ttest_1samp(police_salary['Annual Salary'], 86000)

print('stat is  ', stat)
print('P-value for the one-tailed test is ', pval/2)
# Out:
# stat is   12.573116980151957
# P-value for the one-tailed test is  2.4100985740030478e-36

# %% [markdown]
# **Answer:**
# The P-value is less than 0.05, which means we reject $H_0:$  (_mean of police's salaries this year are <= $86000/year_)

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here:

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here:

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Your code here:

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
