# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
# your code here
import pandas as pd

data = pd.read_csv('Sentiment140.csv')

# %%
data.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
data.shape
# Out:
# (1600000, 6)

# %%
sample_data = data.sample(frac=0.001, replace=False, random_state=1)
sample_data.shape
# Out:
# (1600, 6)

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
import re

def clean_up(s):
    
    cleaned = re.sub(r"http[s]?\S+", "", s)
    clean = re.findall('[^a-zA-Z]',s)
    
    for i in clean:
        cleaned = cleaned.replace(i, ' ')
        
    cleaned = cleaned.lower()
    return cleaned

sample_data['text_processed'] = list(map(clean_up, sample_data['text']))
sample_data.head(3)
# Out:
#         target         ids                          date      flag  \
# 514293       0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282       0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727       0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 514293    Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282    PatCashin  So I had a dream last night. I  remember a sig...
# 403727  deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
#
#                                            text_processed
# 514293  i miss nikki nu nu already  shes always there ...
# 142282  so i had a dream last night  i  remember a sig...
# 403727   girlyghost ohh poor sickly you      hugs   ho...

# %%
from nltk.tokenize import word_tokenize
import nltk

def tokenize(s):
    tokens = word_tokenize(s)
    return tokens

sample_data['text_processed'] = list(map(tokenize, sample_data['text_processed']))    
sample_data.head(3)
# Out:
#         target         ids                          date      flag  \
# 514293       0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282       0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727       0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 514293    Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282    PatCashin  So I had a dream last night. I  remember a sig...
# 403727  deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
#
#                                            text_processed
# 514293  [i, miss, nikki, nu, nu, already, shes, always...
# 142282  [so, i, had, a, dream, last, night, i, remembe...
# 403727  [girlyghost, ohh, poor, sickly, you, hugs, hop...

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet

def stem_and_lemmatize(l):
    ps = PorterStemmer()
    lemmatizer = WordNetLemmatizer() 
    lemmatized = [lemmatizer.lemmatize(word) for word in l]
    
    stemmed = [ps.stem(w) for w in lemmatized]
    
    return stemmed

sample_data['text_processed'] = list(map(stem_and_lemmatize, sample_data['text_processed']))  
sample_data.head(3)
# Out:
#         target         ids                          date      flag  \
# 514293       0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282       0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727       0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 514293    Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282    PatCashin  So I had a dream last night. I  remember a sig...
# 403727  deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
#
#                                            text_processed
# 514293  [i, miss, nikki, nu, nu, alreadi, she, alway, ...
# 142282  [so, i, had, a, dream, last, night, i, rememb,...
# 403727  [girlyghost, ohh, poor, sickli, you, hug, hope...

# %%
from nltk.corpus import stopwords
import nltk

def remove_stopwords(l):
    without_sw = [word for word in l if not word in stopwords.words()]
    return without_sw

sample_data['text_processed'] = list(map(remove_stopwords, sample_data['text_processed']))  
sample_data.head(3)
# Out:
#         target         ids                          date      flag  \
# 514293       0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282       0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727       0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 514293    Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282    PatCashin  So I had a dream last night. I  remember a sig...
# 403727  deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
#
#                                            text_processed
# 514293    [miss, nikki, alreadi, alway, need, thank, xxx]
# 142282  [dream, last, night, rememb, sign, clearli, to...
# 403727  [girlyghost, ohh, poor, sickli, hug, hope, fee...

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
from nltk.probability import FreqDist

# %%
w_list =[]

for i in range(sample_data.shape[0]):
    t = sample_data.text_processed.iloc[i]
    w_list = w_list+t

# %%
f_dist = FreqDist(w_list)
f_dist
# Out:
# FreqDist({'go': 143, 'get': 116, 'wa': 112, 'day': 111, 'good': 94, 'like': 84, 'love': 82, 'got': 80, 'work': 78, 'today': 67, ...})

# %%
top = list(f_dist)[0:5000]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
sample_data['positive'] = sample_data['target'].copy()
sample_data['positive'] = sample_data['positive'].replace([4],1)
sample_data['positive'] = sample_data['positive'].astype('bool')

# %%
sample_data.head(3)
# Out:
#         target         ids                          date      flag  \
# 514293       0  2190584004  Tue Jun 16 03:08:48 PDT 2009  NO_QUERY
# 142282       0  1881451988  Fri May 22 04:42:15 PDT 2009  NO_QUERY
# 403727       0  2058252964  Sat Jun 06 14:34:17 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 514293    Vicki_Gee  i miss nikki nu nu already  shes always there ...
# 142282    PatCashin  So I had a dream last night. I  remember a sig...
# 403727  deelectable  @girlyghost ohh poor sickly you   (((hugs)) ho...
#
#                                            text_processed  positive
# 514293    [miss, nikki, alreadi, alway, need, thank, xxx]     False
# 142282  [dream, last, night, rememb, sign, clearli, to...     False
# 403727  [girlyghost, ohh, poor, sickli, hug, hope, fee...     False

# %%
def find_features(words):
    features = {}
    
    for w in top:
        features[w] = (w in words)

    return features

# target : 0 = negative, 4 = positive

# %%
#find_features(sample_data.text_processed.iloc[1])

# %%
features = [(find_features(sample_data['text_processed'].iloc[x]), sample_data['positive'].iloc[x]) for x in range(sample_data.shape[0])]

# %%
features[1]
# Out:
# ({'go': False,
#   'get': True,
#   'wa': False,
#   'day': False,
#   'good': False,
#   'like': False,
#   'love': False,
#   'got': False,
#   'work': False,
#   'today': False,
#   'time': False,
#   'see': False,
#   'amp': False,
#   'thank': False,
#   'back': False,
#   'quot': False,
#   'watch': False,
#   'feel': False,
#   'still': False,
#   'lol': False,
#   'home': False,
#   'realli': False,
#   'miss': False,
#   'think': False,
#   'look': False,
#   'hope': False,
#   'new': False,
#   'make': False,
#   'know': False,
#   'last': True,
#   'oh': False,
#   'well': False,
#   'night': True,
#   'wish': False,
#   'right': False,
#   'morn': False,
#   'sorri': False,
#   'wait': False,
#   'whi': False,
#   'need': False,
#   'great': False,
#   'onli': False,
#   'bad': False,
#   'much': False,
#   'rain': False,
#   'week': False,
#   'sad': False,
#   'follow': False,
#   'fun': False,
#   'school': False,
#   'tomorrow': False,
#   'haha': False,
#   'way': False,
#   'twitter': False,
#   'tonight': False,
#   'guy': False,
#   'happi': False,
#   'best': False,
#   'sure': False,
#   'better': False,
#   'even': False,
#   'bed': False,
#   'would': False,
#   'phone': False,
#   'sleep': False,
#   'first': False,
#   'hate': False,
#   'thing': False,
#   'ye': False,
#   'talk': False,
#   'say': False,
#   'could': False,
#   'nice': False,
#   'peopl': False,
#   'car': False,
#   'hour': False,
#   'ok': False,
#   'hey': False,
#   'yeah': False,
#   'friend': False,
#   'though': False,
#   'hi': False,
#   'mayb': False,
#   'littl': False,
#   'life': False,
#   'wan': False,
#   'show': False,
#   'head': False,
#   'year': False,
#   'alreadi': False,
#   'keep': False,
#   'start': False,
#   'read': False,
#   'tweet': False,
#   'next': False,
#   'everyon': False,
#   'veri': False,
#   'bore': False,
#   'sick': False,
#   'gt': False,
#   'movi': False,
#   'cant': False,
#   'yay': False,
#   'excit': False,
#   'leav': False,
#   'alway': False,
#   'job': True,
#   'seem': False,
#   'play': False,
#   'final': False,
#   'anoth': False,
#   'use': False,
#   'ever': False,
#   'ani': False,
#   'gon': False,
#   'lt': False,
#   'tell': False,
#   'long': False,
#   'enjoy': False,
#   'find': False,
#   'said': True,
#   'lost': False,
#   'live': False,
#   'away': False,
#   'done': False,
#   'never': False,
#   'saw': False,
#   'ur': False,
#   'x': False,
#   'weekend': False,
#   'finish': False,
#   'someon': False,
#   'readi': False,
#   'stop': False,
#   'thought': False,
#   'pleas': False,
#   'help': False,
#   'awesom': False,
#   'found': False,
#   'someth': False,
#   'weather': False,
#   'let': False,
#   'doe': False,
#   'guess': False,
#   'call': False,
#   'wonder': False,
#   'eye': False,
#   'summer': False,
#   'cool': False,
#   'walk': False,
#   'yesterday': False,
#   'hot': False,
#   'glad': False,
#   'beauti': False,
#   'yet': False,
#   'becaus': False,
#   'actual': False,
#   'around': False,
#   'least': False,
#   'ugh': False,
#   'sun': False,
#   'game': False,
#   'sunday': False,
#   'hurt': False,
#   'girl': False,
#   'exam': False,
#   'omg': False,
#   'sound': False,
#   'god': False,
#   'later': False,
#   'th': False,
#   'parti': False,
#   'iphon': False,
#   'noth': False,
#   'mean': False,
#   'suck': False,
#   'hahaha': False,
#   'tire': False,
#   'went': False,
#   'made': False,
#   'amaz': False,
#   'run': False,
#   'w': False,
#   'befor': False,
#   'move': False,
#   'earli': False,
#   'wow': False,
#   'stay': False,
#   'late': False,
#   'hear': False,
#   'dont': False,
#   'sooo': False,
#   'okay': False,
#   'song': False,
#   'damn': False,
#   'shop': False,
#   'must': False,
#   'luck': False,
#   'eat': False,
#   'crap': False,
#   'xx': False,
#   'b': False,
#   'pictur': False,
#   'mother': False,
#   'everi': False,
#   'give': False,
#   'kid': False,
#   'everyth': False,
#   'tho': False,
#   'drink': False,
#   'post': False,
#   'r': False,
#   'wake': False,
#   'rememb': True,
#   'lot': False,
#   'happen': False,
#   'tv': False,
#   'real': False,
#   'sunni': False,
#   'saturday': False,
#   'funni': False,
#   'realiz': False,
#   'chang': False,
#   'may': False,
#   'listen': False,
#   'old': False,
#   'put': False,
#   'gone': False,
#   'quit': False,
#   'worri': False,
#   'monday': False,
#   'hous': False,
#   'forward': False,
#   'word': False,
#   'world': False,
#   'sinc': False,
#   'red': False,
#   'email': False,
#   'anyth': False,
#   'free': False,
#   'babi': False,
#   'cold': False,
#   'hug': False,
#   'soon': False,
#   'month': False,
#   'place': False,
#   'st': False,
#   'book': False,
#   'bit': False,
#   'true': False,
#   'aw': False,
#   'check': False,
#   'mom': False,
#   'studi': False,
#   'music': False,
#   'decid': False,
#   'person': False,
#   'dude': False,
#   'two': False,
#   'forgot': False,
#   'rock': False,
#   'birthday': False,
#   'dinner': False,
#   'headach': False,
#   'far': False,
#   'forget': False,
#   'team': False,
#   'mani': False,
#   'shit': False,
#   'whole': False,
#   'ah': False,
#   'onlin': False,
#   'ask': False,
#   'big': False,
#   'sign': True,
#   'site': False,
#   'load': False,
#   'turn': False,
#   'heart': False,
#   'abl': False,
#   'mtv': False,
#   'award': False,
#   'awww': False,
#   'dear': False,
#   'relax': False,
#   'video': False,
#   'boy': False,
#   'togeth': False,
#   'hard': False,
#   'hair': False,
#   'beach': False,
#   'part': False,
#   'cute': False,
#   'probabl': False,
#   'mac': False,
#   'definit': False,
#   'news': False,
#   'updat': False,
#   'outsid': False,
#   'f': False,
#   'line': False,
#   'busi': False,
#   'brother': False,
#   'shoot': False,
#   'almost': False,
#   'bought': False,
#   'stupid': False,
#   'meet': False,
#   'buy': False,
#   'pay': False,
#   'didnt': False,
#   'favorit': False,
#   'caus': False,
#   'cri': False,
#   'fall': False,
#   'toni': False,
#   'lunch': False,
#   'jealou': False,
#   'woke': False,
#   'total': False,
#   'hehe': False,
#   'famili': False,
#   'hang': False,
#   'dream': True,
#   'shift': False,
#   'p': False,
#   'plan': False,
#   'sooooo': False,
#   'weird': False,
#   'train': False,
#   'math': False,
#   'afternoon': False,
#   'seat': False,
#   'alright': False,
#   'lake': False,
#   'ahhh': False,
#   'complet': False,
#   'enough': False,
#   'youtub': False,
#   'interest': False,
#   'bring': False,
#   'pain': False,
#   'stuff': False,
#   'shoe': False,
#   'repli': False,
#   'onc': False,
#   'race': False,
#   'blue': False,
#   'hello': False,
#   'without': False,
#   'kinda': False,
#   'ago': False,
#   'soo': False,
#   'awak': False,
#   'batteri': False,
#   'window': False,
#   'drive': False,
#   'ran': False,
#   'els': False,
#   'www': False,
#   'internet': False,
#   'vote': False,
#   'class': False,
#   'send': False,
#   'congratul': False,
#   'welcom': False,
#   'shower': False,
#   'joy': False,
#   'mad': False,
#   'wors': False,
#   'fail': False,
#   'pretti': False,
#   'cream': False,
#   'lose': False,
#   'pack': False,
#   'came': False,
#   'album': False,
#   'bird': False,
#   'websit': False,
#   'issu': False,
#   'question': False,
#   'link': False,
#   'flu': False,
#   'super': False,
#   'top': False,
#   'fav': False,
#   'pro': False,
#   'serious': False,
#   'bless': False,
#   'facebook': False,
#   'foot': False,
#   'mind': False,
#   'breakfast': False,
#   'count': False,
#   'draw': False,
#   'ticket': False,
#   'break': False,
#   'clean': False,
#   'lie': False,
#   'fit': False,
#   'taylor': False,
#   'sort': False,
#   'coupl': False,
#   'lucki': False,
#   'silli': False,
#   'camp': False,
#   'friday': False,
#   'either': False,
#   'memori': False,
#   'soooo': False,
#   'anymor': False,
#   'ive': False,
#   'win': False,
#   'high': False,
#   'heard': False,
#   'paper': False,
#   'kill': False,
#   'coffe': False,
#   'photo': False,
#   'stori': False,
#   'blog': False,
#   'yup': False,
#   'flight': False,
#   'laptop': False,
#   'fell': False,
#   'left': False,
#   'fine': False,
#   'power': False,
#   'sore': False,
#   'cours': False,
#   'offic': False,
#   'chill': False,
#   'block': False,
#   'wit': False,
#   'wed': False,
#   'might': False,
#   'smile': False,
#   'order': False,
#   'mileycyru': False,
#   'poor': False,
#   'second': False,
#   'kept': False,
#   'upset': False,
#   'lay': False,
#   'chocol': False,
#   'dr': False,
#   'luv': False,
#   'ice': False,
#   'rule': False,
#   'ride': False,
#   'hayfev': False,
#   'normal': False,
#   'form': False,
#   'gym': False,
#   'chat': False,
#   'bet': False,
#   'apart': False,
#   'ring': False,
#   'offici': False,
#   'slow': False,
#   'thunder': False,
#   'andyhurleyday': False,
#   'bike': False,
#   'catch': False,
#   'basketbal': False,
#   'answer': False,
#   'comment': False,
#   'bake': False,
#   'vacat': False,
#   'hubbi': False,
#   'age': False,
#   'jonasbroth': False,
#   'air': False,
#   'wont': False,
#   'sleepi': False,
#   'hill': False,
#   'juli': False,
#   'visit': False,
#   'moon': False,
#   'case': False,
#   'revis': False,
#   'shall': False,
#   'nope': False,
#   'airport': False,
#   'low': False,
#   'quick': False,
#   'present': False,
#   'test': False,
#   'cd': False,
#   'tune': False,
#   'north': False,
#   'expect': False,
#   'parent': False,
#   'safe': False,
#   'fb': False,
#   'church': False,
#   'moment': False,
#   'seen': False,
#   'although': False,
#   'open': False,
#   'beat': False,
#   'suppos': False,
#   'dad': False,
#   'swim': False,
#   'perfect': False,
#   'continu': False,
#   'anyway': False,
#   'pick': False,
#   'especi': False,
#   'spent': False,
#   'cuz': False,
#   'ff': False,
#   'adam': False,
#   'hell': False,
#   'fan': False,
#   'instead': False,
#   'yea': False,
#   'mike': False,
#   'fuck': False,
#   'card': False,
#   'kind': False,
#   'side': False,
#   'winter': False,
#   'niec': False,
#   'close': False,
#   'yep': False,
#   'anyon': False,
#   'store': False,
#   'itun': False,
#   'half': False,
#   'practic': False,
#   'stand': False,
#   'tree': False,
#   'hangov': False,
#   'lmao': False,
#   'cooki': False,
#   'boyfriend': False,
#   'sweet': False,
#   'road': False,
#   'lotu': False,
#   'near': False,
#   'nick': False,
#   'save': False,
#   'bigger': False,
#   'small': False,
#   'water': False,
#   'account': False,
#   'nite': False,
#   'somewher': False,
#   'hr': False,
#   'join': False,
#   'buddi': False,
#   'colleg': False,
#   'trick': False,
#   'disappoint': False,
#   'danc': False,
#   'dead': False,
#   'tommcfli': False,
#   'money': False,
#   'nap': False,
#   'tast': False,
#   'bump': False,
#   'tummi': False,
#   'hit': False,
#   'hav': False,
#   'green': False,
#   'mix': False,
#   'launch': False,
#   'couldnt': False,
#   'folk': False,
#   'extra': False,
#   'goin': False,
#   'warm': False,
#   'grandpa': False,
#   'gettin': False,
#   'trust': False,
#   'honestli': False,
#   'wine': False,
#   'ach': False,
#   'rest': False,
#   'contact': False,
#   'extrem': False,
#   'bum': False,
#   'fight': False,
#   'woo': False,
#   'voic': False,
#   'pink': False,
#   'franc': False,
#   'scene': False,
#   'peep': False,
#   'bloodi': False,
#   'accid': False,
#   'alot': False,
#   'promis': False,
#   'river': False,
#   'googl': False,
#   'father': False,
#   'radio': False,
#   'goodi': False,
#   'goodby': False,
#   'librari': False,
#   'kate': False,
#   'eva': False,
#   'info': False,
#   'depress': False,
#   'cheer': False,
#   'touch': False,
#   'ouch': False,
#   'concert': False,
#   'star': False,
#   'delet': False,
#   'imma': False,
#   'doc': False,
#   'upload': False,
#   'brought': False,
#   'pocket': False,
#   'g': False,
#   'problem': False,
#   'bc': False,
#   'fl': False,
#   'pm': False,
#   'freak': False,
#   'felt': False,
#   'jay': False,
#   'meh': False,
#   'laugh': False,
#   'nail': False,
#   'blood': False,
#   'season': False,
#   'bro': False,
#   'fair': False,
#   'sadli': False,
#   'short': False,
#   'mile': False,
#   'stuck': False,
#   'crazi': False,
#   'doubt': False,
#   'easi': False,
#   'crappi': False,
#   'idk': False,
#   'addict': False,
#   'current': False,
#   'lab': False,
#   'awsom': False,
#   'coast': False,
#   'major': False,
#   'sunshin': False,
#   'bother': False,
#   'child': False,
#   'lazi': False,
#   'tuesday': False,
#   'bull': False,
#   'xo': False,
#   'ladi': False,
#   'english': False,
#   'street': False,
#   'slept': False,
#   'daughter': False,
#   'fluffi': False,
#   'blackberri': False,
#   'attent': False,
#   'scare': False,
#   'ny': False,
#   'doggi': False,
#   'hold': False,
#   'bag': False,
#   'understand': False,
#   'fabul': False,
#   'salesman': False,
#   'due': False,
#   'boo': False,
#   'miley': False,
#   'app': False,
#   'goodnight': False,
#   'broke': False,
#   'pj': False,
#   'nighti': False,
#   'thanx': False,
#   'fill': False,
#   'anim': False,
#   'plu': False,
#   'grow': False,
#   'tom': False,
#   'event': False,
#   'tool': False,
#   'entertain': False,
#   'king': False,
#   'argh': False,
#   'attack': False,
#   'christ': False,
#   'mee': False,
#   'horribl': False,
#   'flower': False,
#   'babe': False,
#   'transform': False,
#   'wing': False,
#   'knew': False,
#   'possibl': False,
#   'organis': False,
#   'dure': False,
#   'laker': False,
#   'type': False,
#   'lame': False,
#   'deserv': False,
#   'hero': False,
#   'freakin': False,
#   'thursday': False,
#   'stomach': False,
#   'drop': False,
#   'bill': False,
#   'camera': False,
#   'csi': False,
#   'beer': False,
#   'behind': False,
#   'program': False,
#   'joey': False,
#   'avail': False,
#   'apolog': False,
#   'graduat': False,
#   'hilari': False,
#   'date': False,
#   'fave': False,
#   'tim': False,
#   'dang': False,
#   'ear': False,
#   'trip': False,
#   'sushi': False,
#   'offer': False,
#   'sometim': False,
#   'chanc': False,
#   'fed': False,
#   'wrong': False,
#   'page': False,
#   'woop': False,
#   'edit': False,
#   'food': False,
#   'sent': False,
#   'usa': False,
#   'imag': False,
#   'shot': False,
#   'convers': False,
#   'doubl': False,
#   'london': False,
#   'mall': False,
#   'past': False,
#   'bitch': False,
#   'steph': False,
#   'took': False,
#   'doctor': False,
#   'david': False,
#   'thx': False,
#   'shout': False,
#   'burn': False,
#   'lesson': False,
#   'jk': False,
#   'hahah': False,
#   'histori': False,
#   'idea': False,
#   'followfriday': False,
#   'toast': False,
#   'secret': False,
#   'episod': False,
#   'sweater': False,
#   'cover': False,
#   'servic': False,
#   'easier': False,
#   'product': False,
#   'bye': False,
#   'stress': False,
#   'blah': False,
#   'xxx': False,
#   'clearli': True,
#   'told': True,
#   'ohh': False,
#   'full': False,
#   'basket': False,
#   'tea': False,
#   'nd': False,
#   'heh': False,
#   'kitti': False,
#   'nurs': False,
#   'search': False,
#   'engin': False,
#   'alexalltimelow': False,
#   'woohoo': False,
#   'spectacular': False,
#   'tha': False,
#   'death': False,
#   'bout': False,
#   'plane': False,
#   'cupcak': False,
#   'earth': False,
#   'structur': False,
#   'roller': False,
#   'coaster': False,
#   'four': False,
#   'hv': False,
#   'option': False,
#   'absolut': False,
#   'legend': False,
#   'finger': False,
#   'level': False,
#   'deep': False,
#   'leg': False,
#   'storag': False,
#   'garden': False,
#   'glass': False,
#   'miser': False,
#   'basebal': False,
#   'tournament': False,
#   'chloe': False,
#   'urg': False,
#   'white': False,
#   'talent': False,
#   'howev': False,
#   'chicago': False,
#   'ireland': False,
#   'prayer': False,
#   'fam': False,
#   'creek': False,
#   'label': False,
#   'wife': False,
#   'pen': False,
#   'alcohol': False,
#   'yr': False,
#   'becom': False,
#   'cake': False,
#   'orang': False,
#   'juic': False,
#   'facial': False,
#   'dork': False,
#   'mornin': False,
#   'heat': False,
#   'background': False,
#   'june': False,
#   'firefox': False,
#   'base': False,
#   'everybodi': False,
#   'retir': False,
#   'sob': False,
#   'ipod': False,
#   'experi': False,
#   'depend': False,
#   'wind': False,
#   'dy': False,
#   'nicol': False,
#   'univers': False,
#   'swollen': False,
#   'nom': False,
#   'fianc': False,
#   'poorli': False,
#   'icon': False,
#   'posit': False,
#   'row': False,
#   'spring': False,
#   'april': False,
#   'paid': False,
#   'sheet': False,
#   'toilet': False,
#   'hungov': False,
#   'aww': False,
#   'learn': False,
#   'leno': False,
#   'stalker': False,
#   'circl': False,
#   'kick': False,
#   'naughti': False,
#   'recoveri': False,
#   'dress': False,
#   'pull': False,
#   'guilti': False,
#   'south': False,
#   'warp': False,
#   'set': False,
#   'gorgeou': False,
#   'ew': False,
#   'five': False,
#   'agre': False,
#   'bio': False,
#   'greek': False,
#   'mulder': False,
#   'sculli': False,
#   'central': False,
#   'earlier': False,
#   'sister': False,
#   'oooh': False,
#   'meant': False,
#   'middl': False,
#   'comput': False,
#   'badli': False,
#   'sooooooo': False,
#   'dark': False,
#   'termin': False,
#   'nugget': False,
#   'bff': False,
#   'project': False,
#   'angela': False,
#   'drew': False,
#   'cancel': False,
#   'overcast': False,
#   'pant': False,
#   'bawl': False,
#   'grumbl': False,
#   'obvious': False,
#   'bright': False,
#   'mow': False,
#   'grass': False,
#   'bf': False,
#   'emili': False,
#   'manag': False,
#   'heck': False,
#   'arcad': False,
#   'ohhhh': False,
#   'noon': False,
#   'tweeti': False,
#   'main': False,
#   'brand': False,
#   'sneez': False,
#   'allerg': False,
#   'gosh': False,
#   'britney': False,
#   'hast': False,
#   'surf': False,
#   'impress': False,
#   'whilst': False,
#   'stare': False,
#   'arghhhh': False,
#   'edward': False,
#   'loud': False,
#   'band': False,
#   'assign': False,
#   'appli': False,
#   'michel': False,
#   'cut': False,
#   'shud': False,
#   'matter': False,
#   'group': False,
#   'txt': False,
#   'co': False,
#   'everytim': False,
#   'ant': False,
#   'toastcommun': False,
#   'ikr': False,
#   'pl': False,
#   'mountain': False,
#   'eh': False,
#   'warn': False,
#   'verizon': False,
#   'wee': False,
#   'thnx': False,
#   'lover': False,
#   'involv': False,
#   'holi': False,
#   'delici': False,
#   'yoga': False,
#   'everyday': False,
#   'volunt': False,
#   'center': False,
#   'nasti': False,
#   'recommend': False,
#   'plenti': False,
#   'sex': False,
#   'lookin': False,
#   'mess': False,
#   'ooh': False,
#   'inde': False,
#   'wear': False,
#   'bbq': False,
#   'jordanknight': False,
#   'america': False,
#   'carlo': False,
#   'uh': False,
#   'appl': False,
#   'asleep': False,
#   'arm': False,
#   'mari': False,
#   'figur': False,
#   'dri': False,
#   'sorrow': False,
#   'snap': False,
#   'attend': False,
#   'gut': False,
#   'sing': False,
#   'rob': False,
#   'burnt': False,
#   'breez': False,
#   'michael': False,
#   'ate': False,
#   'frozen': False,
#   'user': False,
#   'sky': False,
#   'loung': False,
#   'wi': False,
#   'art': False,
#   'celtic': False,
#   'troubl': False,
#   'countri': False,
#   'def': False,
#   'terribl': False,
#   'kennedi': False,
#   ...},
#  False)

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
